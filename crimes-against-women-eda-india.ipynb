# %% [raw]
# [<h4>dataset</h4>](https://www.kaggle.com/datasets/sailajamahapatro/crimes-against-women-from-2011-2021-in-india)
#
# This dataset consists of the count of a variety of crimes agaist women in India in 10 years (2011-2021) in various states. I have tried to visualize perform EDA on this dataset to understand
# 1. how bad the crimes against women in South India really has been in this period of time
# 2. what type of crimes have been most common

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/crimes-against-women-from-2011-2021-in-india/factors of women-1.xlsx

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/kaggle/input/crimes-against-women-from-2011-2021-in-india/factors of women-1.xlsx", index_col = 0)
df.head()
# Out:
#                  STATES  YEAR  RAPE  KIDNAP & ABDUCTION  DOWRY DEATHS  \
# S.NO
# 1        Andhra Pradesh  2011  1442                1612           599
# 2     Arunachal Pradesh  2011    42                  60             0
# 3                 Assam  2011  1700                3192           121
# 4                 Bihar  2011   934                3050          1413
# 5          Chhattisgarh  2011  1053                 365           104
#
#       CRUETLY BY HUSBAND OR HIS RELATIVES  HUMAN TRAFFICKING  \
# S.NO
# 1                                   13376                  0
# 2                                      18                  0
# 3                                    5246                  2
# 4                                    2607                 10
# 5                                     834                  2
#
#       ASSAULT ON MODESTY  SEXUAL HARRASSMENT  IMORTAL TRAFFICKING  \
# S.NO
# 1                      0                3658                  497
# ...

# %%
df.STATES = df.STATES.astype("string")
df.dtypes.to_frame()
# Out:
#                                           0
# STATES                               string
# YEAR                                  int64
# RAPE                                  int64
# KIDNAP & ABDUCTION                    int64
# DOWRY DEATHS                          int64
# CRUETLY BY HUSBAND OR HIS RELATIVES   int64
# HUMAN TRAFFICKING                     int64
# ASSAULT ON MODESTY                    int64
# SEXUAL HARRASSMENT                    int64
# IMORTAL TRAFFICKING                   int64
# TOTAL CRIMES AGAINST WOMEN            int64

# %%
print(df.STATES.unique())
# Out:
# <StringArray>
# [   'Andhra Pradesh', 'Arunachal Pradesh',             'Assam',
#              'Bihar',      'Chhattisgarh',               'Goa',
#            'Gujarat',           'Haryana',  'Himachal Pradesh',
#    'Jammu & Kashmir',         'Jharkhand',         'Karnataka',
#             'Kerala',    'Madhya Pradesh',       'Maharashtra',
#            'Manipur',         'Meghalaya',           'Mizoram',
#           'Nagaland',            'Odisha',            'Punjab',
#          'Rajasthan',            'Sikkim',        'Tamil Nadu',
#          'Telangana',           'Tripura',     'Uttar Pradesh',
#        'Uttarakhand',       'West Bengal',     'A & N Islands',
#         'Chandigarh',        'D&N Haveli',       'Daman & Diu',
#           'Delhi UT',       'Lakshadweep',        'Puducherry']
# Length: 36, dtype: string

# %%
states = ['Karnataka', 'Kerala', 'Telangana', 'Andhra Pradesh','Tamil Nadu']
for s in states:
    dh = df.loc[df.STATES == s]
    dh.plot(x='YEAR', y=list(dh.loc[:, dh.columns != 'YEAR']), figsize=(11,7))
    plt.figtext(1,0,s,backgroundcolor='green', color='white', size='x-large')
    plt.legend(loc='upper right', borderpad = 2)
    #print("test")

# %%
print(df.columns)
len(df.columns) - 3
# Out:
# Index(['STATES', 'YEAR', 'RAPE', 'KIDNAP & ABDUCTION', 'DOWRY DEATHS',
#        'CRUETLY BY HUSBAND OR HIS RELATIVES', 'HUMAN TRAFFICKING',
#        'ASSAULT ON MODESTY', 'SEXUAL HARRASSMENT', 'IMORTAL TRAFFICKING',
#        'TOTAL CRIMES AGAINST WOMEN'],
#       dtype='object')
# 8

# %%
#CRUETLY BY HUSBAND OR HIS RELATIVES
#DOWRY DEATHS
#TOTAL CRIMES AGAINST WOMEN

for s in states:
    c = sum(df.loc[df.STATES == s]['CRUETLY BY HUSBAND OR HIS RELATIVES'])
    d = sum(df.loc[df.STATES == s]['DOWRY DEATHS'])
    t = sum(df.loc[df.STATES == s]['TOTAL CRIMES AGAINST WOMEN'])
    #print('Percentage :- ', t - (c+d))
    plt.pie([t-(c+d), c, d], labels = ['Other crimes', 'Cruelty by husbands', 'Dowry deaths'] ,
           shadow = True, explode=[0.2, 0, 0], startangle=90)
    plt.title(s)
    plt.show()
    print('CRUETLY BY HUSBAND OR HIS RELATIVES: ', c)
    print('DOWRY DEATHS: ', d)
    print('TOTAL CRIMES AGAINST WOMEN', t)
    print('~'*100)
# Out:
# CRUETLY BY HUSBAND OR HIS RELATIVES:  33546
# DOWRY DEATHS:  3595
# TOTAL CRIMES AGAINST WOMEN 137835
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# CRUETLY BY HUSBAND OR HIS RELATIVES:  48796
# DOWRY DEATHS:  1271
# TOTAL CRIMES AGAINST WOMEN 153849
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# CRUETLY BY HUSBAND OR HIS RELATIVES:  44276
# DOWRY DEATHS:  1724
# TOTAL CRIMES AGAINST WOMEN 98268
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# CRUETLY BY HUSBAND OR HIS RELATIVES:  96269
# DOWRY DEATHS:  3053
# TOTAL CRIMES AGAINST WOMEN 224965
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# CRUETLY BY HUSBAND OR HIS RELATIVES:  30982
# DOWRY DEATHS:  1259
# TOTAL CRIMES AGAINST WOMEN 94051
# ...

# %% [markdown]
# <h4>To answer the 2 questions asked at the beginning,</h4>
# ​
# 1. the crime rates have been pretty bad
# 2. domestic violence (cruelty by husband and his family and dowry deaths according to this dataset) has sadly been amounting to at least 25% of crimes against women. After all, it all *does* start with the family.
